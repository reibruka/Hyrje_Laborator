# %% [markdown]
# # **Laborator 2** - Git & GitHub
# ---
# - ##### Tema: **Git dhe GitHub**
# - ##### Studenti: Rei Bruka
# - ##### Pedagogu: Ervin Kafexhiu
# - ##### Data: 17.03.2026
# ---
#
# - ##### Qellimi:
#
# Qellimi i ketij laboratori eshte te kuptojme bazat e sistemit te kontrollit te versioneve **Git** dhe perdorimit e
# platformes **GitHub** per ruajtjen dhe dorezimin e projekteve.
#
#
#
# <p>- te kuptojme cfare eshte Git</p>
# <p>- te mesojme si funksionon GitHub</p>
# <p>- te krijojme dhe menaxhojme nje repository</p>
# <p>- te perdorim komandat baze te Git</p>

# %% [markdown]
# ## Hyrje ne Git dhe GitHub
# ---
#
# Git eshte nje sistem per kontrollin e versioneve (version control system) qe ruan historine e ndryshimeve te skedareve te nje projekti.
#
# Ai perdoret gjeresisht ne:
# - zhvillimin e software
# - analiza te te dhenave
# - projekte kerkimore
# - bashkepunim shkencor
#
# GitHub eshte nje platforme online qe perdor Git dhe lejon ruajtjen dhe ndarjen e projekteve ne internet .
#
# Git lejon te:
# - ruash historine e punes
# - rikthej versionet e meparshme
# - bashkpunim me te tjeret ne nje projekt
#
# Pra **Git** ruan historine e punes, ndersa **GitHub** e ruan ate online dhe e ben te akse4

# %% [markdown]
# ## Instalimi dhe Konfigurimi
# ---
#
# **Git mund te shkarkohet nga faqja zyrtare:**
#
# https://git-scm.com/
#
# **Pas instalimit kontrollohet me komanden nga terminali:**
#
# git --version
#
# Nese Git eshte instaluar sakte do te shfaqet versioni.
#
# **Pastaj konfiguron identitetin:**
#
# fit config --global user.name "Emri"
#
# git config --global user.email "email@example.com"
#
# **Kontrollon konfigurimin:**
#
# git config --global --list

# %% [markdown]
# ## Repository
# ---
#
# Nje **Repository (repo)** eshte nje dosje qe permban projektin dhe historine e tij.
#
# Mund te jete:
# - **lokal** (ne kompjuterat tane)
# - **online** ne nje platform hosting (GitHub).
#
# Ai permban:
# - kodin ose dokumentet
# - versionet e meparshme
# - versionet e meparshme

# %% [markdown]
# ## Git Hosting
# ---
# **Git eshte nje mjet lokal, por zakonisht projektet ruhen edhe online.**
#
# Platforma te njohura per **Git hosting** jane:
#
# - GitHub
# - GitLab
# - Bitbucket
#
# Ne kete kurs ne do te perdorim **GitHub**, nje nga platformat me te perdorura ne bote per projekte software dhe kerkimore.
#
# **GitHub lejon:**
#
# - ruajtjen e projekteve online
# - bashkepunim
# - dorezimi e puneve laboratorike

# %% [markdown]
# ## Komandat minimale te Git
# ---
#
# Ne kete laborator perdorim vetem disa komanda baze:
#
# | Komanda | Kuptimi |
# |---------|---------|
# | git init | Krijon nje repository lokal |
# | git status | Tregon ndryshimet ne projekt |
# | git add. | Shton te gjitha ndryshimet |
# | git commit -m "mesazh" | Ruan nje version te ri |
# | git push | Ngarkon ndryshimet ne GitHub |
# | git pull | Merr ndryshimet nga GitHub |

# %% [markdown]
# ## Workflow i Git
# ---
# **Workflow i Git** eshte procesi i ruajtjes dhe ngarkimit te ndryshimeve.
#
# Hapat jane :
#
# **1.** Behen ndryshime ne projekt
#
# **2.** Kontrollohet gjendja me git status
#
# **3.** Shtohen ndryshimet me git add.
#
# **4.** Ruhen versioni me git commit
#
# **5.** Ngarkohet ne GitHub me git push
#
# Ky proces perseritet cdo here qe perditesohet projekti.

# %% [markdown]
# ## Lidhja me GitHub
# ---
# **Per te lidhur projektin lokal me GitHub perdoren keto komanda:**
#
# git remote add origin https://github.com/USERNAME/REPOSITORY.git
#
# git branch -M main
#
# git push -u origin main
#
# Kjo ben qe projekti te lidhet me repository online.

# %% [markdown]
# ##  GitHub Classroom
# ---
#
# **GitHub Classroom** perdoret per dorezimin e detyrave laboratorike.
#
# **Procesi:**
#
# <p>- hapet linku i assignment-it</p>
# <p>- bëhet Accept assignment</p>
# <p>- krijohet repository personal</p>
# <p>- shkarkohet projekti me git clone</p>
# <p>- punohet në raport</p>
# <p>- bëhet git push për dorëzim</p>
#
# Versioni i fundit ne GitHub konsiderohet si versioni final

# %% [markdown]
# ##  Struktura e repository
# ---
#
# Repository duhet të jete i organizuar:
#
# <pre>raport-LAB-two/
# │
# ├── raport.ipynb
# ├── data/
# ├── figures/
# └── README.md</pre>
#
# Kjo ndihmon ne organizimin dhe kuptimin e projektit.

# %% [markdown]
# ## Gabime të zakonshme
# ---
#
# <p>- Mos bëni vetëm commit pa git push</p>
# <p>- Mos dorëzoni notebook pa output</p>
# <p>- Mos përdorni repository të gabuar</p>
#
# Duhet gjithmonë të kontrolloni që skedarët janë ngarkuar në GitHub.

# %% [markdown]
# ## **Diskutimi**
#
# Git rezultoi mjet thelbësor për ndjekjen e ndryshimeve: çdo gjendje e projektit ruhet si një pikë e regjistruar në histori, kështu që gabimet mund të kthehen mbrapsht dhe ecuria e punës mbetet e dokumentuar. Rrjedha bazë e punës — ndryshimi i skedarëve, shtimi i tyre në zonën e përgatitjes, regjistrimi me një mesazh përshkrues dhe dërgimi në GitHub — kërkon disiplinë në fillim, por pas pak përsëritjesh bëhet e natyrshme. Lidhja me GitHub dhe GitHub Classroom e bën dorëzimin e detyrave të menjëhershëm dhe të verifikueshëm, ndërsa struktura e qartë e depos (dosjet `data/`, `figs/` dhe raporti) e lehtëson kontrollin e punës. Gabimet më të zakonshme, si harresa e regjistrimit të ndryshimeve para dërgimit ose puna në vendndodhje të gabuar, shmangen duke kontrolluar rregullisht gjendjen e depos para çdo veprimi.

# %% [markdown]
# ## Perfundim
# ---
#
# **Git dhe GitHub** jane mjete te rendesishme per menaxhimin e projekteve dhe dorëzimin e puneve.
#
# Ato ndihmojnë në ruajtjen e historise se punes dhe organizimin e saj në menyrë efikase.

# %% [markdown]
# ## Vizualizim — Aktiviteti i Commit-eve
#
# Një grafik ilustrues i numrit të commit-eve për ditë gjatë punës me Git/GitHub, i ruajtur në `figs/`.

# %%
import matplotlib.pyplot as plt
from pathlib import Path
Path("figs").mkdir(exist_ok=True)

dita = ["E hënë","E martë","E mërkurë","E enjte","E premte"]
commits = [3, 5, 2, 6, 4]
plt.figure(figsize=(8,4))
plt.bar(dita, commits, color="#27ae60")
plt.xlabel("Dita"); plt.ylabel("Numri i commit-eve")
plt.title("Aktiviteti i commit-eve gjatë javës")
plt.tight_layout()
plt.savefig("figs/commits.png", dpi=150)
plt.show()
