# %% [markdown]
# # Laborator 03- Markdown dhe Struktura e Raportit Laboratorik
# ---
# - ##### Tema: **Markdown dhe Struktura e Raportit Laboratorik**
# - ##### Studenti: Rei Bruka
# - ##### Pedagogu: Ervin Kafexhiu
# - ##### Data: 31.03.2026
# ---
#
# - ##### Qellimi:
# Qellimi i ketij laboratori eshte te mesojme perdorimin e Markdown dhe Python ne Jupyter Notebook, si dhe te krijojme raporte te qarta dhe te strukturuara me shembuj praktike.

# %% [markdown]
# - ##  Cfare eshte Markdown?
# ---
#
# **Markdown** eshe nje gjuhe e thjeshte për formatimin e tekstit qe perdoret per te shkruar dokumente të strukturuara.
#
# Në Jupyter Notebook, qelizat Markdown perdoren per:
# - pershkrimin e eksperimentit
# - shpjegimin e teorise
# - interpretimin e rezultateve
# - shkrimin e formulave matematikore
#
# Markdown eshte shumë i thjeshtë sepse perdor disa simbole baze per te strukturuar tekstin.

# %% [markdown]
# **Ne kete laborator do te perdorim Markdown per:**
# - Tituj dhe nenseksione
# - Tekst te theksuar (bold,italic)
# - Tabela
# - Formula matematike me LaTex
# - Shtimin e figurave
# - Listat dhe code blocks

# %% [markdown]
# **Mjetet qe perdorem:**
#
# Per kete laborator kemi perdorur:
# - **JupyterLab** i instaluar me **Anaconda/Conda++**
# - **Python kernel** per shembujt e kodeve
# - Markdown per formatimin e raporteve
# - Skedarin e figures ('example.png') per shembullin visual

# %% [markdown]
# #         Analiza e punes:

# %% [markdown]
# ---
# - ## Titujt (Headings)
# ---
# Titujt krijohen me simbolin #.
#
# | Sintaksa | Rezultati |
# |----------|-----------|
# | # Titull | Titulli kryesor |
# | ## Seksion | Seksion |
# | ### Nenseksion | Nenseksion |
#
# Ketu po paraqes disa shembull te titujve:
# #### Niveli 4
# ##### Niveli 5
# ###### Niveli 6

# %% [markdown]
# ---
# - ## Formatimi i Tekstit:
# ---
# **Markdown lejon formatim baze te tekstit.**
#
# | Sintaksa | Rezultati |
# |----------|-----------|
# |**Ky tekst eshte i theksuar** | **(bold)** |
# | *Ky tekst eshte i pjerret* | *(italic)* |
# | ***Ky tekst eshte i theksuar dhe i pjerret*** | ***(bold and italic)***
# | ~~Ky tekst eshte me nje vize ne mes~~ | ~~me vize ne mes~~|

# %% [markdown]
# ---
# - ## Shembull Listash:
# ---
#
# ### Liste e Renditur:
# 1. Artikulli i pare
# 2. Artikulli i dyte
#    1. Nenartikull i pare
#    2. Nenartikull i dyte
# 4. Artikull i trete
#
# ### Liste e Parenditur:
# - Pika 1
# - Pika 2
#   - Nenpika 1
#   - Nenpika 2
# - Pika 3

# %% [markdown]
# ---
# - ## Shembull Tabele
# ---
# Tabelat i kam perdorur per te organizuar te dhena ne menyre te qarte dhe te lexueshme. Ketu eshte nje shembull i nje tabele te thjeshte me emra dhe nota:
#
# | Emri | Nota | Vleresim|
# |------|------|---------|
# | Nx1  |  10  | Shkelqyeshem |
# | Nx2  |  9   | Mire|
# | Nx3  |  8   | Mjaftueshem |

# %% [markdown]
# ---
# - ## Shembull Formula Matematikore:
# ---
# Markdown ne Jupyter Notebook lejon perdorimin e formulave matematikore me LaTeX.
#
# Disa shembuj formulash:
#
# $$E = mc^2$$
#
# $$E=m v^2/2$$
#
# $$y'=(3 x^2 - 2 x + 5)' $$
#
# $$ \sum_{i=0}^{5} \frac{x^n}{n!} $$
#
# $$ \int f(x) dx$$

# %% [markdown]
# ---
# - ## Shembull i Linkeve :
# ---
# Nje lidhje drejt GitHub:
#
# [GitHub](https://github.com)

# %% [markdown]
# ---
# - ## Shembull Grafik me Matplotlib:
# ---

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

plt.plot(x, y, marker='o')
plt.title("Grafik Shembull")
plt.xlabel("X")
plt.ylabel("Y")
plt.grid(True)
plt.show()

# %% [markdown]
# ---
# - ## Shembull Figure:
# ---
# Kjo figure tregon nje shembull te perdorimit te figurave ne raportin laboratorik. Figura shtohet me sintaksen:
#
# ![Figura Shembull](figura.png)

# %% [markdown]
# ---
# - ## Shembull i nje Seksioni:
# ---
#
# ## Teoria
#
# Ne kete eksperiment analizojme levizjen e trupit ne renie te lire.
#
# $$
# x(t) = x_0 + v_0 t + \frac{1}{2} g t^2
# $$
#
# ku:
#
# - $x_0$ eshte pozicioni fillestar
# - $v_0$ eshte shpejtësia fillestare
# - $g$ eshte pershpejtimi gravitacional

# %% [markdown]
# ---
# - ## Shembull Python:
# ---

# %%
numrat = [1, 2, 3, 4, 5]
for n in numrat:
    print(f"Numri: {n}, katror: {n**2}")
# Out:
# Numri: 1, katror: 1
# Numri: 2, katror: 4
# Numri: 3, katror: 9
# Numri: 4, katror: 16
# Numri: 5, katror: 25

# %%
def katror(n):
    return n**2
print(katror(7))
print(katror(10))
# Out:
# 49
# 100

# %% [markdown]
# ![alt text](https://github.com/adam-p/markdown-here/raw/master/src/common/images/icon48.png "Logo Title Text 1")

# %% [markdown]
# ---
# - ##  Struktura e nje Raporti:
# ---
# Titulli i Eksperimentit
#
# - Objektivi-Qellimi i eksperimentit.
# - Teoria-Ligjet dhe formulat.
# - Metoda-Pershkrimi i eksperimentit.
# - Analiza e te Dhenave-Kodi dhe perpunimi.
# - Rezultatet-Grafiket dhe rezultatet.
#
# ## Perfundimi
# -Interpretimi i rezultateve.

# %% [markdown]
# ---
# - ## Burime te Dobishme:
# ---
#
# Markdown Cheat Sheet:
# https://www.markdownguide.org/cheat-sheet/
#
# Scientific Python:
# https://ipgp.github.io/scientific_python_cheat_sheet/

# %% [markdown]
# ---
# - ## Praktika te Mira
# ---
#
# - te perdorim tituj te qarte
# - te shpjegojm çfare bejm dhe pse
# - te perdorim formulat ne LaTeX
# - te interpretojme i rezultatet eshte shume e rendesishme

# %% [markdown]
# ## **Diskutimi**
#
# Në këtë laborator mësova të përdor Markdown për të dokumentuar raportet laboratorike dhe Python për shembuj të thjeshtë. Përdora tituj të niveleve të ndryshme, tekst të theksuar, lista të renditura e të parenditura, tabela, figura, blloqe kodi dhe formula matematike, dhe këto mjete e bëjnë raportin të strukturuar dhe të lehtë për t'u kuptuar. Vlera kryesore e Markdown qëndron në thjeshtësinë e tij: me pak shenja teksti arrihet një paraqitje e pastër dhe e njëtrajtshme, ndërsa kombinimi i qelizave të tekstit me ato të kodit brenda së njëjtës fletore lejon që shpjegimi, llogaritja dhe rezultati të qëndrojnë bashkë në një dokument të vetëm.

# %% [markdown]
# ## Vizualizim — Përfshirja e një Figure në Markdown
#
# Markdown-i lejon përfshirjen e figurave. Më poshtë krijojmë një grafik shembull dhe e ruajmë në `figs/` për ta referuar në raport.

# %%
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
Path("figs").mkdir(exist_ok=True)

x = np.linspace(-3, 3, 200)
plt.figure(figsize=(8,4))
plt.plot(x, np.exp(-x**2), color="#8e44ad")
plt.fill_between(x, np.exp(-x**2), alpha=0.2, color="#8e44ad")
plt.xlabel("x"); plt.ylabel("exp(-x²)")
plt.title("Shembull grafiku për përfshirje në Markdown")
plt.grid(alpha=0.3); plt.tight_layout()
plt.savefig("figs/shembull_grafik.png", dpi=150)
plt.show()
