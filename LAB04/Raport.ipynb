# %% [markdown]
# # Lab Report: Introduction to Python
# **Author:** Your Name
# **Course:** Intro Lab
# **Date:** 2026-04-07

# %% [markdown]
# ## Introduction
# This report introduces the Python programming language. The goal is to understand basic syntax, data types, and simple operations using Python.

# %% [markdown]
# ## Objectives
# - Learn basic Python syntax
# - Work with variables and data types
# - Write and execute simple functions
# - Display and analyze results

# %% [markdown]
# ## Theory
# Python is a high-level, interpreted programming language known for its simplicity and readability. It supports multiple programming paradigms and is widely used in web development, data science, automation, and more.

# %%
# Example 1: Variables and Data Types
name = "Rei"
age = 20
height = 1.75

print(name, age, height)

# %%
# Example 2: Function
def square(number):
    return number ** 2

result = square(4)
print("Square:", result)

# %%
# Example 3: Conditional Statement
number = 10

if number % 2 == 0:
    print("Even number")
else:
    print("Odd number")

# %% [markdown]
# ## Results
# The code examples demonstrate:
# - Correct variable assignment and printing
# - Function creation and execution
# - Use of conditional statements
#
# All outputs match expected results.

# %% [markdown]
# ## Conclusion
# This lab provided a basic introduction to Python programming. The exercises helped build a foundation in syntax, logic, and problem-solving using Python.
