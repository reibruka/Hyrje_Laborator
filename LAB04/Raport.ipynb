# %% [markdown]
# # **Laborator 4 - Python per Analizen Shkencore**
# ---
# - ##### Tema: **Python - Numpy , Matplotlib dhe Scipy**
# - ##### Studenti: Rei Bruka
# - ##### Pedagogu: Ervin Kafexhiu
# - ##### Data: 7.04.2026
# - ##### Qellimi:  Qellimi i ketij laboratori eshte te njohim bazat e programimit ne Python, te perdorim bibliotekat **Numpy** , **Matplotlib** dhe **Scipy**.
#
#
#
# Gjate ketij ushtrimi do te :
#
# &nbsp;- Krijojme dhe perdorim vektore
#
# &nbsp;- Kryejme llogaritje numerike
#
# &nbsp;- Paraqesim te dhenat ne menyre grafike
#
# Keto mjete jane shume te rendesishme ne analizen e te dhenave dhe ne punet shkencore.

# %% [markdown]
# ## Hyrje ne Python
# ---
# Python eshte nje gjuhe programimi moderne dhe shume e perdorur, e njohur per thjeshtesine dhe lehtesine ne perdorim.
#
# Ajo perdoret gjeresisht ne:
# - analize te te dhenave
# - inteligjence artificiale
# - zhvillim aplikacionesh
#
# Nje nga arsyet pse Python eshte kaq popullor eshte sepse kodi eshte i qarte dhe i lexueshem.
#
# Kjo e ben ate shume te pershtatshem per studentet fillestar.

# %% [markdown]
# ## Biblioteka Python: NumPy , Matploltlib dhe Scipy
# ---
# Ne kete laborator perdorim tre biblioteka shume te rendesishme:
#
# - **NumPy** perdoret per llogaritje numerike dhe ofron mbeshtetje per vektore, matrica dhe funksione matematike.
# - **Matplotlib** perdoret per vizualizimin grafik te te dhenave, si grafike linjore, histograme dhe diagrame kolonash.
# - **Scipy** perdoret per analiza dhe fitting
#
# Keto biblioteka jane shume te rendesishme per pune shkencore dhe analize te te dheave.

# %% [markdown]
# ## Shembuj rreth tyre:
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
emri = "Horgito"
print("Miresevjen %s" %emri)
# Out:
# Miresevjen Horgito

# %%
uname = "Horgito"
passw = "********"

# %%
print ("user name=%s"%uname)
print ("password=%s"%passw)
print (f"user name={uname}")
print (f"password={passw}")
# Out:
# user name=Gito-Dev
# password=secreeet
# user name=Gito-Dev
# password=secreeet

# %%
l =[0, -3, 3.14, "Prill", "Luleshtrydhe" , "Kompjuter"]

print(f'Lista ka {len(l)} elemente.')
# Out:
# Lista ka 6 elemente.

# %%
print (l[2])
# Out:
# 3.14

# %%
print (l[4])
# Out:
# Luleshtrydhe

# %%
print(l[1:4])
# Out:
# [-3, 3.14, 'Prill']

# %%
for element in l:
    print(element)
# Out:
# 0
# -3
# 3.14
# Prill
# Luleshtrydhe
# Kompjuter

# %%
for i in range(-7,0,-1):
    print(l[i])

# %% [markdown]
# ### Shembull me zar:

# %%
import numpy as np

zari=np.array([1,2,3,4,5,6])
N_hedhje = 100

indx = np.random.randint(0,high=len(zari),size=100)

print(zari[indx])
# Out:
# [4 2 6 1 6 4 4 1 6 4 6 1 3 1 2 4 5 1 6 2 1 5 5 4 1 1 2 2 3 4 1 4 3 4 2 1 1
#  4 5 4 1 5 6 2 5 5 5 5 4 6 3 3 2 6 4 5 3 6 6 6 1 5 6 1 2 5 5 2 2 3 2 1 3 1
#  4 6 2 5 3 1 5 3 5 1 5 1 6 1 3 1 2 6 1 2 2 4 1 4 1 5]

# %%
import numpy as np

zari=np.array([1,2,3,4,5,6])
N_hedhje = 100

indx = np.random.randint(0,high=len(zari),size=100)
rezultati=zari[indx]


print(np.mean(rezultati))
print(21/6)
# Out:
# 3.61
# 3.5

# %%
import numpy as np

zari=np.array([1,2,3,4,5,6])
N_hedhje = 100

def Matje(N_hedhje):
    indx = np.random.randint(0,high=len(zari),size=100)
    rezultati=zari[indx]
    return rezultati

N_hedhje = 100
rezultati = Matje(N_hedhje)
print(np.mean(rezultati))
print(21/6)
# Out:
# 3.31
# 3.5

# %%
import numpy as np

zari=np.array([1,2,3,4,5,6])
N_hedhje = 100

def Matje(N_hedhje):
    indx = np.random.randint(0,high=len(zari),size=N_hedhje)
    rezultati=zari[indx]
    return rezultati

N_hedhje = 100
rezultati = Matje(N_hedhje)
print(np.mean(rezultati))
print(21/6)
# Out:
# 3.62
# 3.5

# %%
zar = np.random.randint(1, 7, size=100)
print(zar)
# Out:
# [2 3 4 6 3 3 1 2 1 5 3 5 3 1 1 6 5 4 3 1 1 3 5 2 2 1 5 6 2 3 4 6 2 3 5 4 5
#  6 3 2 5 6 4 2 6 4 5 3 1 2 5 1 6 3 2 6 2 4 5 5 3 1 2 4 4 6 4 5 3 3 2 5 6 2
#  4 4 3 1 1 5 2 4 4 5 5 5 4 3 6 6 2 2 1 5 4 4 6 6 1 2]

# %%
plt.hist(zar, bins=6)
plt.title("Simulimi i Zarit")
plt.xlabel("Numrat")
plt.ylabel("Shpeshtesia")

plt.show()

# %% [markdown]
# ### Shembull: **Fit linear**

# %%
import numpy as np

x = np.array([1,2,3,4])
y = np.array([2,4,6,8])

coeff = np.polyfit(x,y,1)

slope = coeff[0]
intercept = coeff[1]

# %%
y = slope * x + intercept

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([1,2,3,4])
y = np.array([2.1,4.2,6.1,8.0])

coeff = np.polyfit(x,y,1)

fit = coeff[0]*x + coeff[1]

plt.scatter(x,y,label="Data")
plt.plot(x,fit,label="Fit")

plt.xlabel("x")
plt.ylabel("y")

plt.legend()
plt.show()

# %% [markdown]
# ### Shembull: **Grafik Histogram**

# %%
import matplotlib.pyplot as plt
import numpy as np

zari=np.array([1,2,3,4,5,6])
N_hedhje = 100

def Matje(N_hedhje):
    indx = np.random.randint(0,high=len(zari),size=N_hedhje)
    rezultati=zari[indx]
    return np.mean(rezultati)

N_hedhje = 100
N_perseritje = 10000

rezultatet = []

for i in range(N_perseritje):
    mesatarja = (Matje(N_hedhje))
    rezultatet.append(mesatarja)

rezultatet = np.array(rezultatet)
#print(rezultatet)
#print(21/6)

#plt.plot(rezultatet , color'red')
plt.hist(rezultatet,bins=30)
plt.show()
plt.hist?
# Out:
# Signature:
# plt.hist(
#     x: 'ArrayLike | Sequence[ArrayLike]',
#     bins: 'int | Sequence[float] | str | None' = None,
#     *,
#     range: 'tuple[float, float] | None' = None,
#     density: 'bool' = False,
#     weights: 'ArrayLike | None' = None,
#     cumulative: 'bool | float' = False,
#     bottom: 'ArrayLike | float | None' = None,
#     histtype: "Literal['bar', 'barstacked', 'step', 'stepfilled']" = 'bar',
#     align: "Literal['left', 'mid', 'right']" = 'mid',
#     orientation: "Literal['vertical', 'horizontal']" = 'vertical',
#     rwidth: 'float | None' = None,
#     log: 'bool' = False,
#     color: 'ColorType | Sequence[ColorType] | None' = None,
#     label: 'str | Sequence[str] | None' = None,
#     stacked: 'bool' = False,
#     data=None,
#     **kwargs,
# ) -> 'tuple[np.ndarray | list[np.ndarray], np.ndarray, BarContainer | Polygon | list[BarContainer | Polygon]]'
# Docstring:
# Compute and plot a histogram.
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0,10,100)
y = np.sin(x)

plt.plot(x,y)
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.title("Funksioni sinus")
plt.grid()

plt.show()

# %% [markdown]
# ## **Diskutimi**
#
# Shembujt e trajtuar treguan rolin plotësues të bibliotekave shkencore të Python: NumPy mundëson punën e shpejtë me vargje numerike dhe llogaritjet statistikore, Matplotlib e kthen rezultatin numerik në grafikë të lexueshëm, ndërsa SciPy ofron mjete më të specializuara si përshtatja e funksioneve. Simulimi me zar ilustroi se si shpërndarjet statistikore dalin natyrshëm nga përsëritja e shumë provave dhe se si histogrami i afrohet shpërndarjes teorike me rritjen e numrit të hedhjeve. Përshtatja lineare tregoi se si nga të dhëna me zhurmë mund të nxirren parametrat e një modeli, ndërsa histogramet nxorën në pah rëndësinë e paraqitjes vizuale për të kuptuar shpërndarjen e vlerave. Në tërësi, kombinimi i këtyre mjeteve e bën Python një mjedis të plotë për analizën e të dhënave laboratorike.

# %% [markdown]
# ## Perfundim
#
# Gjate ketij laboratori, mesuam bazat e programimit ne Python. Perdorem NumPy per llogaritje numerike dhe Matplotlib per krijimin e grafikeve.
# Keto mjete jane shume te dobishme per pune shkencore dhe vizualizim te te dhenave.
#
# Ne laborator perdorem Python per:
# - manipulimin e te dhenave (**NumPy**)
# - grafiket (**Matplotlib**)
# - analiza dhe modele (**SciPy**)
#
# Ne **Jupyter Notebook** kombinuam:
# - Markdown -> dokumentim
# - Python -> analiza

# %% [markdown]
# ## Vizualizim — Funksione me Python/NumPy
#
# Demonstrojmë përdorimin e NumPy dhe Matplotlib duke vizatuar disa funksione bazë dhe duke e ruajtur figurën në `figs/`.

# %%
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
Path("figs").mkdir(exist_ok=True)

x = np.linspace(0, 5, 200)
plt.figure(figsize=(8,4.5))
for p, lbl in [(1,"x"),(2,"x²"),(0.5,"√x")]:
    plt.plot(x, x**p, label=f"y = {lbl}")
plt.xlabel("x"); plt.ylabel("y")
plt.title("Funksione bazë në Python")
plt.legend(); plt.grid(alpha=0.3); plt.tight_layout()
plt.savefig("figs/funksionet.png", dpi=150)
plt.show()
