# %% [markdown]
# # LAB06 - Matja e madhesive Baze
# ---
# - ##### Tema: **Matjet me kaliber.**
# - ##### Studenti: Rei Bruka
# - ##### Pedagogu: Ervin Kafexhiu
# - ##### Data: 15.04.2026
# ---

# %% [markdown]
# ## Qëllimi
#
# Qëllimi i këtij laboratori është matja e përmasave të objekteve të vogla me tri metoda të ndryshme — me vizore, me kaliber pa nonius dhe me kaliber me nonius — dhe krahasimi i rezultateve për të kuptuar rolin e rezolucionit të instrumentit në saktësinë e matjes.

# %% [markdown]
# ## Tabela e matjeve
#
# | Objekti | Me vizore | Me kaliber (pa nonius) | Me kaliber (me nonius) |
# |---------|-----------|------------------------|------------------------|
# | 100 g   | 3.2 cm    | 33.1 mm                | 33.12 mm               |
# | 20 g    | 2.2 cm    | 22.2 mm                | 22.24 mm               |
# | 10 g    | 1.4 cm    | 15.4 mm                | 15.40 mm               |

# %% [markdown]
# ## Vizualizim — Krahasimi i Metodave të Matjes
#
# Ndërtojmë një grafik me shtylla që krahason matjet e të njëjtave objekte me vizore, kaliber (pa nonius) dhe kaliber (me nonius), të ruajtur në `figs/`.

# %%
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
Path("figs").mkdir(exist_ok=True)

objektet = ["100 g", "20 g", "10 g"]
vizore  = [32.0, 22.0, 14.0]   # mm (3.2/2.2/1.4 cm)
kaliber = [33.1, 22.2, 15.4]   # mm
nonius  = [33.12, 22.24, 15.40]# mm

x = np.arange(len(objektet)); w = 0.25
fig, ax = plt.subplots(figsize=(8,4.5))
ax.bar(x-w, vizore,  w, label="Vizore")
ax.bar(x,   kaliber, w, label="Kaliber (pa nonius)")
ax.bar(x+w, nonius,  w, label="Kaliber (me nonius)")
ax.set_xticks(x); ax.set_xticklabels(objektet)
ax.set_xlabel("Objekti"); ax.set_ylabel("Përmasa (mm)")
ax.set_title("Krahasimi i metodave të matjes")
ax.legend(); ax.grid(axis="y", alpha=0.3); fig.tight_layout()
fig.savefig("figs/krahasimi_matjeve.png", dpi=150); plt.show()

# %% [markdown]
# ## **Diskutimi**
#
# Krahasimi i tri metodave tregon qartë rolin e rezolucionit të instrumentit: vizorja lexohet deri në milimetrin më të afërt, kaliberi pa nonius deri në të dhjetën e milimetrit, ndërsa noniusi e çon leximin deri në të qindtën e milimetrit. Vlerat e të njëjtit objekt përputhen ndërmjet metodave brenda pasigurive përkatëse, por kaliberi me nonius jep vlerën më të besueshme, sepse zvogëlon si gabimin e leximit ashtu edhe ndikimin e vlerësimit me sy. Dallimi më i dukshëm u vu re te objekti 10 g, ku vizorja dha 14 mm ndërsa kaliberi 15.4 mm — diferencë që tregon sa lehtë futet një gabim i madh kur shkalla e instrumentit është e trashë dhe objekti i vogël. Ky ushtrim ilustron parimin e përgjithshëm se zgjedhja e instrumentit duhet t'i përshtatet saktësisë së kërkuar të matjes.

# %% [markdown]
# ## Përfundimi
#
# Në këtë laborator u matën përmasat e tre objekteve me vizore, me kaliber pa nonius dhe me kaliber me nonius. Rezultatet treguan se sa më i lartë rezolucioni i instrumentit, aq më e saktë dhe më e besueshme është matja: vizorja jep vetëm një vlerësim të përafërt, ndërsa kaliberi me nonius lejon leximin deri në të qindtën e milimetrit. Krahasimi grafik i metodave e bëri të dukshëm këtë dallim dhe tregoi se zgjedhja e instrumentit duhet të bëhet gjithmonë në përputhje me saktësinë që kërkon matja.
